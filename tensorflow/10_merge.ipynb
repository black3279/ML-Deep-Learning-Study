# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/bike.csv')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df_1 = df.head(2)

# %%
df_2 = df.tail(2)

# %%
df_bind = pd.concat([df_1, df_2])
df_bind
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
df_bind = pd.concat([df_1, df_2], axis = 1)
df_bind
# Out:
#                   datetime  season  holiday  workingday weather  temp   atemp  \
# 0      2011-01-01 00:00:00     1.0      0.0         0.0     1.0  9.84  14.395
# 1      2011-01-01 01:00:00     1.0      0.0         0.0     1.0  9.02  13.635
# 10884                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
# 10885                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
#
#        humidity  windspeed  casual  ...  holiday  workingday weather   temp  \
# 0          81.0        0.0     3.0  ...      NaN         NaN     NaN    NaN
# 1          80.0        0.0     8.0  ...      NaN         NaN     NaN    NaN
# 10884       NaN        NaN     NaN  ...      0.0         1.0     1.0  13.94
# 10885       NaN        NaN     NaN  ...      0.0         1.0     1.0  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0         NaN       NaN        NaN     NaN         NaN    NaN
# 1         NaN       NaN        NaN     NaN         NaN    NaN
# ...

# %%
df_bind = pd.concat([df_1, df_2.reset_index(drop = True)], axis = 1)
df_bind
# Out:
#               datetime  season  holiday  workingday weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0       1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0       1  9.02  13.635
#
#    humidity  windspeed  casual  ...  holiday  workingday weather   temp  \
# 0        81        0.0       3  ...        0           1       1  13.94
# 1        80        0.0       8  ...        0           1       1  13.12
#
#     atemp  humidity  windspeed  casual  registered  count
# 0  17.425        61     6.0032      12         117    129
# 1  16.665        66     8.9981       4          84     88
#
# [2 rows x 24 columns]

# %%
df_3 = df.iloc[3:5,]
df_3
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df_bind = pd.concat([df_3.reset_index(drop = True), 
                     df_2.reset_index(drop = True)], axis = 1)
df_bind
# Out:
#               datetime  season  holiday  workingday weather  temp   atemp  \
# 0  2011-01-01 03:00:00       1        0           0       1  9.84  14.395
# 1  2011-01-01 04:00:00       1        0           0       1  9.84  14.395
#
#    humidity  windspeed  casual  ...  holiday  workingday weather   temp  \
# 0        75        0.0       3  ...        0           1       1  13.94
# 1        75        0.0       0  ...        0           1       1  13.12
#
#     atemp  humidity  windspeed  casual  registered  count
# 0  17.425        61     6.0032      12         117    129
# 1  16.665        66     8.9981       4          84     88
#
# [2 rows x 24 columns]

# %%
df_list = pd.read_csv('./data/join_list.csv', encoding="CP949")
df_room = pd.read_csv('./data/join_room.csv', encoding="CP949")
df_list.head(2)
# Out:
#     team    No member
# 0  TWICE  1287     미나
# 1  TWICE  1788     나연

# %%
df_list.join(df_room, how = "left")
# Out:
#           team    No member  floor  room name
# 0        TWICE  1287     미나    3.0  3G-A   미나
# 1        TWICE  1788     나연    3.0  3G-B   나연
# 2        TWICE  1408     다현    3.0  3G-C   다현
# 3        TWICE  1881     정연    4.0  4G-A   정연
# 4        TWICE  1937     지효    4.0  4G-B   지효
# 5        TWICE  1045     채연    4.0  4G-C   채연
# 6        TWICE  1525     모모    5.0  5G-A   모모
# 7        TWICE  1887     쯔위    5.0  5G-B   쯔위
# 8        TWICE  1547     사나    5.0  5G-C   사나
# 9   Red Velvet  1452    아이린    NaN   NaN  NaN
# 10  Red Velvet  1948     웬디    NaN   NaN  NaN
# 11  Red Velvet  1448     슬기    NaN   NaN  NaN
# 12  Red Velvet  1670     조이    NaN   NaN  NaN
# 13  Red Velvet  1565     예리    NaN   NaN  NaN

# %%
df_list.join(df_room, how = "inner")
# Out:
#     team    No member  floor  room name
# 0  TWICE  1287     미나      3  3G-A   미나
# 1  TWICE  1788     나연      3  3G-B   나연
# 2  TWICE  1408     다현      3  3G-C   다현
# 3  TWICE  1881     정연      4  4G-A   정연
# 4  TWICE  1937     지효      4  4G-B   지효
# 5  TWICE  1045     채연      4  4G-C   채연
# 6  TWICE  1525     모모      5  5G-A   모모
# 7  TWICE  1887     쯔위      5  5G-B   쯔위
# 8  TWICE  1547     사나      5  5G-C   사나

# %%
df_list = df_list.sort_values(by = "No").reset_index(drop = True)
df_list
# Out:
#           team    No member
# 0        TWICE  1045     채연
# 1        TWICE  1287     미나
# 2        TWICE  1408     다현
# 3   Red Velvet  1448     슬기
# 4   Red Velvet  1452    아이린
# 5        TWICE  1525     모모
# 6        TWICE  1547     사나
# 7   Red Velvet  1565     예리
# 8   Red Velvet  1670     조이
# 9        TWICE  1788     나연
# 10       TWICE  1881     정연
# 11       TWICE  1887     쯔위
# 12       TWICE  1937     지효
# 13  Red Velvet  1948     웬디

# %%
df_list.join(df_room, how = "left")
# Out:
#           team    No member  floor  room name
# 0        TWICE  1045     채연    3.0  3G-A   미나
# 1        TWICE  1287     미나    3.0  3G-B   나연
# 2        TWICE  1408     다현    3.0  3G-C   다현
# 3   Red Velvet  1448     슬기    4.0  4G-A   정연
# 4   Red Velvet  1452    아이린    4.0  4G-B   지효
# 5        TWICE  1525     모모    4.0  4G-C   채연
# 6        TWICE  1547     사나    5.0  5G-A   모모
# 7   Red Velvet  1565     예리    5.0  5G-B   쯔위
# 8   Red Velvet  1670     조이    5.0  5G-C   사나
# 9        TWICE  1788     나연    NaN   NaN  NaN
# 10       TWICE  1881     정연    NaN   NaN  NaN
# 11       TWICE  1887     쯔위    NaN   NaN  NaN
# 12       TWICE  1937     지효    NaN   NaN  NaN
# 13  Red Velvet  1948     웬디    NaN   NaN  NaN

# %%
df_list.merge(df_room, left_on = "member", right_on = "name",
             how = "inner")
# Out:
#     team    No member  floor  room name
# 0  TWICE  1045     채연      4  4G-C   채연
# 1  TWICE  1287     미나      3  3G-A   미나
# 2  TWICE  1408     다현      3  3G-C   다현
# 3  TWICE  1525     모모      5  5G-A   모모
# 4  TWICE  1547     사나      5  5G-C   사나
# 5  TWICE  1788     나연      3  3G-B   나연
# 6  TWICE  1881     정연      4  4G-A   정연
# 7  TWICE  1887     쯔위      5  5G-B   쯔위
# 8  TWICE  1937     지효      4  4G-B   지효

# %%
df_list.merge(df_room, left_on = "member", right_on = "name",
             how = "left")
# Out:
#           team    No member  floor  room name
# 0        TWICE  1045     채연    4.0  4G-C   채연
# 1        TWICE  1287     미나    3.0  3G-A   미나
# 2        TWICE  1408     다현    3.0  3G-C   다현
# 3   Red Velvet  1448     슬기    NaN   NaN  NaN
# 4   Red Velvet  1452    아이린    NaN   NaN  NaN
# 5        TWICE  1525     모모    5.0  5G-A   모모
# 6        TWICE  1547     사나    5.0  5G-C   사나
# 7   Red Velvet  1565     예리    NaN   NaN  NaN
# 8   Red Velvet  1670     조이    NaN   NaN  NaN
# 9        TWICE  1788     나연    3.0  3G-B   나연
# 10       TWICE  1881     정연    4.0  4G-A   정연
# 11       TWICE  1887     쯔위    5.0  5G-B   쯔위
# 12       TWICE  1937     지효    4.0  4G-B   지효
# 13  Red Velvet  1948     웬디    NaN   NaN  NaN
