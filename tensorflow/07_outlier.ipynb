# %%
import pandas as pd
df = pd.read_csv('./data/bike.csv')
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df_sub = df.loc[df["casual"] >= df["casual"].quantile(0.99), :]
df_sub
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 2751   2011-07-03 13:00:00       3        0           0        1  32.80
# 2775   2011-07-04 13:00:00       3        1           0        2  31.98
# 3687   2011-09-04 13:00:00       3        0           0        2  31.98
# 4236   2011-10-08 13:00:00       4        0           0        1  25.42
# 4237   2011-10-08 14:00:00       4        0           0        1  25.42
# ...                    ...     ...      ...         ...      ...    ...
# 10204  2012-11-10 14:00:00       4        0           0        1  22.14
# 10227  2012-11-11 13:00:00       4        0           0        1  22.14
# 10228  2012-11-11 14:00:00       4        0           0        1  24.60
# 10229  2012-11-11 15:00:00       4        0           0        1  22.96
# 10230  2012-11-11 16:00:00       4        0           0        1  22.14
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df_sub["casual"].quantile([0,1])
# Out:
# 0.0    241.0
# 1.0    367.0
# Name: casual, dtype: float64

# %%
import numpy as np

# %%
df["season"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df["temp"].max()
# Out:
# 41.0

# %%
df["count"].quantile(0.99)
# Out:
# 774.1499999999996

# %%
df_sub = df.loc[df["count"] >= df["count"].quantile(0.99), :]
df_sub.head(2)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  atemp  \
# 6658  2012-03-14 17:00:00       1        0           1        1  28.70  31.82
# 6779  2012-03-19 18:00:00       1        0           1        1  26.24  31.06
#
#       humidity  windspeed  casual  registered  count
# 6658        28     6.0032     140         642    782
# 6779        57    16.9979     120         681    801

# %%
df_sub["count"].quantile([0,1])
# Out:
# 0.0    775.0
# 1.0    977.0
# Name: count, dtype: float64

# %%
iris = pd.read_csv("./data/iris_missing.csv")
iris.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
len(iris)
# Out:
# 150

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris_drop1 = iris.dropna(how = "any")
iris_drop1.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
len(iris_drop1)
# Out:
# 126

# %%
iris_drop2 = iris.dropna(how = "all")
iris_drop2.head(10)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa
# 7           5.0          3.4           NaN          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           NaN          0.1  setosa

# %%
len(iris_drop2)
# Out:
# 150

# %%
iris_sub = iris.iloc[:, :-1]
iris_sub.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.1          NaN           NaN          0.2
# 1           4.9          3.0           1.4          0.2

# %%
iris_sub_drop = iris_sub.dropna(how = "all")
len(iris_sub_drop)
# Out:
# 148

# %%
iris_sub_drop.head(10)
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0            5.1          NaN           NaN          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 7            5.0          3.4           NaN          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           NaN          0.1
# 10           5.4          3.7           NaN          0.2
